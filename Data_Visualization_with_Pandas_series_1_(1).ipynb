# %% [markdown]
# # Data Visualization with Pandas - 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ** Plot style is dark backgroud**

# %%
plt.style.use("dark_background")

# %% [markdown]
# ## Plotting graph with plot() method

# %% [markdown]
# **Generating Data Using random.rand(1000) which means 0 to 999 rows and "data" is storing variable**

# %%
data=pd.Series(np.random.randn(1000).cumsum())  #cumulative sum
data
# Out:
# 0       0.078758
# 1      -0.563512
# 2       0.472048
# 3       1.300300
# 4       1.406409
#          ...
# 995    68.520166
# 996    69.614037
# 997    70.641284
# 998    70.557764
# 999    69.022205
# Length: 1000, dtype: float64

# %%
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# **Generating random data using numpy function random.randn(100,4) which means random numbers in 100 rows and 4 columns and "df1" is variable

# %%
df1 = pd.DataFrame(np.random.randn(100, 4),columns=list('ABCD'))
df1
# Out:
#            A         B         C         D
# 0  -0.668247  0.669105 -0.159929  2.234847
# 1  -1.925432  0.518107 -1.119151 -0.786624
# 2  -0.803845  0.403101 -0.876444 -0.245112
# 3  -0.857758  0.220042  0.794001  0.660552
# 4   0.382684 -1.602888  2.282182  0.327407
# ..       ...       ...       ...       ...
# 95  1.574781 -0.379696  0.302330  0.138326
# 96 -0.946590 -0.121629  0.036854 -1.505615
# 97  0.060598 -0.504792  1.481054 -1.104601
# 98  0.487923 -0.233580 -0.601588  0.123262
# 99 -2.937522 -0.589479  1.290635  0.442277
#
# [100 rows x 4 columns]

# %% [markdown]
# ** Ploting cumulative sum of stored data in df1 **

# %%
df1 = df1.cumsum() # cumsum() is  cumulative sum

# %%
df1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Charts Examples

# %% [markdown]
# **iloc[10]selects data from a DataFrame by row and column number from "df1" and plotting that data in bar graph**

# %%
df1.iloc[10].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ** generating data using random.rand(7,3) means 7 rows and 3 columns**

# %%
df2=pd.DataFrame(np.random.rand(7,3), columns=list("ABC")) # Column names
df2
# Out:
#           A         B         C
# 0  0.333159  0.009053  0.949165
# 1  0.107493  0.898424  0.036982
# 2  0.331223  0.688734  0.157660
# 3  0.029017  0.647014  0.649867
# 4  0.639269  0.983374  0.640520
# 5  0.699623  0.083825  0.392100
# 6  0.556676  0.084918  0.545749

# %% [markdown]
# **generating bar graph **

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# **horizontal bar chart**

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Histograms

# %% [markdown]
# **Pulling Data from Github Directly**

# %%
csv_url = "https://github.com/plotly/datasets/blob/master/iris-data.csv?raw=true"
iris = pd.read_csv(csv_url)

# %% [markdown]
# **Using this data**

# %%
iris.columns=["sepal_length","sepal_width", "petal_length",
              "petal_width", "species"]

# %% [markdown]
# You can access this data set [here](https://github.com/tirendazacademy/data-visualization-with-python).

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.hist(alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
bins=25

# %%
iris.plot.hist(alpha=1, stacked=True, bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris["sepal_width"].plot.hist(orientation="horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal_length"].diff().hist()
# Out:
# <Axes: >

# %%
iris.hist(color="blue", alpha=1, bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.hist("petal_length",by="species")
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Boxplot charts

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors={'boxes': 'Red', 'whiskers': 'blue','medians': 'Black', 'caps': 'Green'}

# %%
iris.plot.box(color=colors)
# Out:
# <Axes: >

# %%
iris.plot.box(vert=False)
# Out:
# <Axes: >

# %%
iris.boxplot()
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"]=(8,8)
plt.style.use("ggplot")
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %% [markdown]
# Don't forget to follow on [Tirendaz Academy YouTube](https://www.youtube.com/channel/UCFU9Go20p01kC64w-tmFORw), [Twitter](https://twitter.com/TirendazAcademy), [Medium](https://tirendazacademy.medium.com), [GitHub](https://github.com/TirendazAcademy) and [LinkedIn](https://www.linkedin.com/in/tirendaz-academy)
