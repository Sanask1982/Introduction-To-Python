# %% [markdown]
# **Connecting to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Giving Path of Excel File to open**

# %%
import pandas as pd
df1 = pd.read_excel("/content/drive/MyDrive/Healthcare_Patient1_Data.xlsx")
df1
# Out:
#                                Patient ID             Name  Age  Gender  \
# 0    b5da0c78-ff16-4755-9f4f-d74b125ec565   Matthew Rogers   82    Male
# 1    848071f6-9ba9-482e-a2d5-a46b31e76658   Willie Walters   55    Male
# 2    223dc8c1-99f8-4a9b-ac74-77b5d4469090  Rachel Cummings    3  Female
# 3    271b26c3-e451-41cc-a2c1-a318b6b23ddb   Kristin Knight   12    Male
# 4    e775df1d-7aa9-40f4-b9bb-da8215da6002   Austin Herrera   91    Male
# ..                                    ...              ...  ...     ...
# 995  11125b6b-e948-4e71-95af-064369ab8adb       Lee Turner   24  Female
# 996  b1afc0fe-f361-4720-a57b-2458cbc4143c       Ryan Meyer    4    Male
# 997  eb0cb73e-4dee-4a59-944c-ff0a195e2c3c  Jennifer Gordon   34   Other
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440  Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9     John Hammond   57    Male
#
#     Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# ...

# %% [markdown]
# **Using describe() function to Analyze all numerical **data** **

# %%
df1.describe()
# Out:
#                Age               Date of Visit  Blood Pressure (Systolic)  \
# count  1000.000000                        1000                1000.000000
# mean     49.901000  2024-10-19 22:17:45.600000                 135.182000
# min       0.000000         2024-04-21 00:00:00                  90.000000
# 25%      25.750000         2024-07-20 00:00:00                 112.000000
# 50%      50.000000         2024-10-21 00:00:00                 137.000000
# 75%      75.000000         2025-01-18 00:00:00                 158.000000
# max     100.000000         2025-04-21 00:00:00                 180.000000
# std      28.748699                         NaN                  26.238814
#
#        Blood Pressure (Diastolic)   Heart Rate          BMI  \
# count                 1000.000000  1000.000000  1000.000000
# mean                    90.476000    79.643000    27.381400
# min                     60.000000    60.000000    15.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient ID                  1000 non-null   object
#  1   Name                        1000 non-null   object
#  2   Age                         1000 non-null   int64
#  3   Gender                      1000 non-null   object
#  4   Date of Visit               1000 non-null   datetime64[ns]
#  5   Diagnosis                   1000 non-null   object
#  6   Blood Pressure (Systolic)   1000 non-null   int64
#  7   Blood Pressure (Diastolic)  1000 non-null   int64
#  8   Heart Rate                  1000 non-null   int64
#  9   BMI                         1000 non-null   float64
#  10  Medication Prescribed       1000 non-null   object
#  11  Follow-up Required          1000 non-null   object
#  12  Hospital / Department       1000 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# Patient ID                    0
# Name                          0
# Age                           0
# Gender                        0
# Date of Visit                 0
# Diagnosis                     0
# Blood Pressure (Systolic)     0
# Blood Pressure (Diastolic)    0
# Heart Rate                    0
# BMI                           0
# Medication Prescribed         0
# Follow-up Required            0
# Hospital / Department         0
# Doctor Name                   0
# Cost of Visit (USD)           0
# Insurance Covered (%)         0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.isna().sum()
# Out:
# Patient ID                    0
# Name                          0
# Age                           0
# Gender                        0
# Date of Visit                 0
# Diagnosis                     0
# Blood Pressure (Systolic)     0
# Blood Pressure (Diastolic)    0
# Heart Rate                    0
# BMI                           0
# Medication Prescribed         0
# Follow-up Required            0
# Hospital / Department         0
# Doctor Name                   0
# Cost of Visit (USD)           0
# Insurance Covered (%)         0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.head(6)
# Out:
#                              Patient ID             Name  Age  Gender  \
# 0  b5da0c78-ff16-4755-9f4f-d74b125ec565   Matthew Rogers   82    Male
# 1  848071f6-9ba9-482e-a2d5-a46b31e76658   Willie Walters   55    Male
# 2  223dc8c1-99f8-4a9b-ac74-77b5d4469090  Rachel Cummings    3  Female
# 3  271b26c3-e451-41cc-a2c1-a318b6b23ddb   Kristin Knight   12    Male
# 4  e775df1d-7aa9-40f4-b9bb-da8215da6002   Austin Herrera   91    Male
# 5  a661a714-0959-4e39-9263-c30d8b0e08ca    Jeffrey Mason   83    Male
#
#   Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# 0    2024-07-25      Asthma                        137
# 1    2024-11-08   Back Pain                        158
# 2    2024-12-30  Depression                        158
# 3    2024-09-04  Depression                        136
# 4    2025-04-13   Back Pain                        113
# 5    2024-10-31   Back Pain                        149
#
#    Blood Pressure (Diastolic)  Heart Rate   BMI Medication Prescribed  \
# ...

# %%
df1.tail(6)
# Out:
#                                Patient ID             Name  Age  Gender  \
# 994  d9813ec7-861a-4f93-ad10-be70b2309d9e     Carmen Costa   33    Male
# 995  11125b6b-e948-4e71-95af-064369ab8adb       Lee Turner   24  Female
# 996  b1afc0fe-f361-4720-a57b-2458cbc4143c       Ryan Meyer    4    Male
# 997  eb0cb73e-4dee-4a59-944c-ff0a195e2c3c  Jennifer Gordon   34   Other
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440  Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9     John Hammond   57    Male
#
#     Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# 994    2024-09-20         Flu                        164
# 995    2025-02-14     Anxiety                        132
# 996    2024-12-08   Back Pain                        153
# 997    2024-05-06  Depression                        124
# 998    2025-01-27     Allergy                        145
# 999    2024-11-21     Allergy                        120
#
# ...

# %%
df1[df1 ['Diagnosis']=='Allergy']
# Out:
#                                Patient ID              Name  Age  Gender  \
# 9    f740f2b1-caee-4703-a854-6ecf0ef3bd7e   Brandon Hensley   66   Other
# 36   3af3b3d1-7ac0-46ce-af81-4376b9fa5d8b     Daniel Farley    5  Female
# 38   782cd122-80a5-4164-bb94-daf63e5b5010         Randy Lin   17    Male
# 49   30ced513-cb9f-40ba-8955-f779142c22ed    Jamie Martinez    0   Other
# 53   1d68217c-a338-45b2-9c2c-08b7f6921771    Michelle Davis   56    Male
# ..                                    ...               ...  ...     ...
# 974  d812e175-2113-474f-b818-8d564c296d8b  Jasmine Faulkner   38  Female
# 976  54007f07-6a65-4593-9f55-9adf51a9837c   Brittany Forbes   20    Male
# 981  7ad7b449-47c8-4559-bddc-b338c667bdb5    Francisco Haas   67  Female
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440   Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9      John Hammond   57    Male
#
#     Date of Visit Diagnosis  Blood Pressure (Systolic)  \
# ...

# %%
all=df1[df1 ['Diagnosis']=='Allergy']
all['Name'].count()
# Out:
# np.int64(128)

# %%
all=df1[df1 ['Diagnosis']=='Allergy']
all.count()
# Out:
# Patient ID                    128
# Name                          128
# Age                           128
# Gender                        128
# Date of Visit                 128
# Diagnosis                     128
# Blood Pressure (Systolic)     128
# Blood Pressure (Diastolic)    128
# Heart Rate                    128
# BMI                           128
# Medication Prescribed         128
# Follow-up Required            128
# Hospital / Department         128
# Doctor Name                   128
# Cost of Visit (USD)           128
# Insurance Covered (%)         128
# dtype: int64

# %%
df1['CAT'] = df1['Age'].apply(lambda x: 'Young' if x >= 18 else 'OLD')
df1
# Out:
#                                Patient ID             Name  Age  Gender  \
# 0    b5da0c78-ff16-4755-9f4f-d74b125ec565   Matthew Rogers   82    Male
# 1    848071f6-9ba9-482e-a2d5-a46b31e76658   Willie Walters   55    Male
# 2    223dc8c1-99f8-4a9b-ac74-77b5d4469090  Rachel Cummings    3  Female
# 3    271b26c3-e451-41cc-a2c1-a318b6b23ddb   Kristin Knight   12    Male
# 4    e775df1d-7aa9-40f4-b9bb-da8215da6002   Austin Herrera   91    Male
# ..                                    ...              ...  ...     ...
# 995  11125b6b-e948-4e71-95af-064369ab8adb       Lee Turner   24  Female
# 996  b1afc0fe-f361-4720-a57b-2458cbc4143c       Ryan Meyer    4    Male
# 997  eb0cb73e-4dee-4a59-944c-ff0a195e2c3c  Jennifer Gordon   34   Other
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440  Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9     John Hammond   57    Male
#
#     Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# ...

# %%
df1['Category'] = 'normal'  # Default value
df1.loc[df1['Age'] > 50, 'Category'] = 'old'
df1.loc[df1['Age'] < 10, 'Category'] = 'young'
df1
# Out:
#                                Patient ID             Name  Age  Gender  \
# 0    b5da0c78-ff16-4755-9f4f-d74b125ec565   Matthew Rogers   82    Male
# 1    848071f6-9ba9-482e-a2d5-a46b31e76658   Willie Walters   55    Male
# 2    223dc8c1-99f8-4a9b-ac74-77b5d4469090  Rachel Cummings    3  Female
# 3    271b26c3-e451-41cc-a2c1-a318b6b23ddb   Kristin Knight   12    Male
# 4    e775df1d-7aa9-40f4-b9bb-da8215da6002   Austin Herrera   91    Male
# ..                                    ...              ...  ...     ...
# 995  11125b6b-e948-4e71-95af-064369ab8adb       Lee Turner   24  Female
# 996  b1afc0fe-f361-4720-a57b-2458cbc4143c       Ryan Meyer    4    Male
# 997  eb0cb73e-4dee-4a59-944c-ff0a195e2c3c  Jennifer Gordon   34   Other
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440  Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9     John Hammond   57    Male
#
#     Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# ...

# %%
df1['Average BP'] = (df1['Blood Pressure (Systolic)'] + df1['Blood Pressure (Diastolic)']) / 2
df1
# Out:
#                                Patient ID             Name  Age  Gender  \
# 0    b5da0c78-ff16-4755-9f4f-d74b125ec565   Matthew Rogers   82    Male
# 1    848071f6-9ba9-482e-a2d5-a46b31e76658   Willie Walters   55    Male
# 2    223dc8c1-99f8-4a9b-ac74-77b5d4469090  Rachel Cummings    3  Female
# 3    271b26c3-e451-41cc-a2c1-a318b6b23ddb   Kristin Knight   12    Male
# 4    e775df1d-7aa9-40f4-b9bb-da8215da6002   Austin Herrera   91    Male
# ..                                    ...              ...  ...     ...
# 995  11125b6b-e948-4e71-95af-064369ab8adb       Lee Turner   24  Female
# 996  b1afc0fe-f361-4720-a57b-2458cbc4143c       Ryan Meyer    4    Male
# 997  eb0cb73e-4dee-4a59-944c-ff0a195e2c3c  Jennifer Gordon   34   Other
# 998  f27fd684-bf2b-43b4-b19f-3fb37729e440  Joshua Randolph   23   Other
# 999  d7f74e19-8b5e-4b76-98c5-1dd2a805b2f9     John Hammond   57    Male
#
#     Date of Visit   Diagnosis  Blood Pressure (Systolic)  \
# ...

# %%
gender = df1[df1 ['Gender']=='Male']
gen_male=gender['Gender'].count()
print (gen_male)
# Out:
# 351

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
import matplotlib.pyplot as plt
df1['Gender'].value_counts().plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
df1['Diagnosis'].value_counts().plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt
df1['BMI'].value_counts().plot.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
df1['Follow-up Required'].value_counts().plot(kind='bar')
plt.show()
