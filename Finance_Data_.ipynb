# %% [markdown]
# **Connecting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Giving Location of Your File**

# %%
import pandas as pd
financedf = pd.read_excel("/content/drive/MyDrive/finance_data.xlsx")
financedf
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage
# ..            ...        ...         ...         ...        ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash
# 97        TXN0098 2024-04-07     2166.33      Income       Cash
# 98        TXN0099 2024-04-08      175.82     Expense       Cash
# 99        TXN0100 2024-04-09      584.06  Investment       Cash
#
# [100 rows x 5 columns]

# %% [markdown]
# **How to Upload A file From Collab After running this command you have to select a file from tab button**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ffed9f2-16a8-444e-96b4-76a682ba9f6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ffed9f2-16a8-444e-96b4-76a682ba9f6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('finance_data.xlsx')
df
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage
# ..            ...        ...         ...         ...        ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash
# 97        TXN0098 2024-04-07     2166.33      Income       Cash
# 98        TXN0099 2024-04-08      175.82     Expense       Cash
# 99        TXN0100 2024-04-09      584.06  Investment       Cash
#
# [100 rows x 5 columns]

# %% [markdown]
# **What df.info() is doing ?
# How many rows and columns there are, Each column's name,How many non-null values each column has,The data type of each column (e.g., int, float, object (string), datetime).
# How much memory the whole DataFrame uses.**

# %%
financedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  100 non-null    object
#  1   Date            100 non-null    datetime64[ns]
#  2   Amount_USD      100 non-null    float64
#  3   Type            100 non-null    object
#  4   Account         100 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# **df.isnull() function creates a table of True/False, where True means the value is missing and False means Value is there **

# %%
financedf.isnull()
# Out:
#     Transaction_ID   Date  Amount_USD   Type  Account
# 0            False  False       False  False    False
# 1            False  False       False  False    False
# 2            False  False       False  False    False
# 3            False  False       False  False    False
# 4            False  False       False  False    False
# ..             ...    ...         ...    ...      ...
# 95           False  False       False  False    False
# 96           False  False       False  False    False
# 97           False  False       False  False    False
# 98           False  False       False  False    False
# 99           False  False       False  False    False
#
# [100 rows x 5 columns]
#     Transaction_ID   Date  Amount_USD   Type  Account
# 0            False  False       False  False    False
# 1            False  False       False  False    False
# 2            False  False       False  False    False
# 3            False  False       False  False    False
# ...

# %% [markdown]
# ** if we include sum() function with isnull() then it will add all the null values or True values**

# %%
financedf.isnull().sum()
# Out:
# Transaction_ID    0
# Date              0
# Amount_USD        0
# Type              0
# Account           0
# dtype: int64
# Transaction_ID    0
# Date              0
# Amount_USD        0
# Type              0
# Account           0
# dtype: int64

# %% [markdown]
# ** Checking Duplicates in Data **

# %%
financedf.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %% [markdown]
# **isna(), is same like isnull()**

# %%
financedf.isna()
# Out:
#     Transaction_ID   Date  Amount_USD   Type  Account
# 0            False  False       False  False    False
# 1            False  False       False  False    False
# 2            False  False       False  False    False
# 3            False  False       False  False    False
# 4            False  False       False  False    False
# ..             ...    ...         ...    ...      ...
# 95           False  False       False  False    False
# 96           False  False       False  False    False
# 97           False  False       False  False    False
# 98           False  False       False  False    False
# 99           False  False       False  False    False
#
# [100 rows x 5 columns]
#     Transaction_ID   Date  Amount_USD   Type  Account
# 0            False  False       False  False    False
# 1            False  False       False  False    False
# 2            False  False       False  False    False
# 3            False  False       False  False    False
# ...

# %% [markdown]
# **Removes all the rows that have any missing value and make changes directly to data frame. dropna() means drop all the missing values**

# %%
financedf.dropna(inplace=True)
financedf
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage
# ..            ...        ...         ...         ...        ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash
# 97        TXN0098 2024-04-07     2166.33      Income       Cash
# 98        TXN0099 2024-04-08      175.82     Expense       Cash
# 99        TXN0100 2024-04-09      584.06  Investment       Cash
#
# [100 rows x 5 columns]
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# ...

# %% [markdown]
# **Checking Starting 3 Rows, head() allows you to check starting rows of your data**

# %%
financedf.head(3)
# Out:
#   Transaction_ID       Date  Amount_USD        Type    Account
# 0        TXN0001 2024-01-01     1903.97  Investment       Cash
# 1        TXN0002 2024-01-02     4756.04  Investment       Cash
# 2        TXN0003 2024-01-03     3673.37     Expense  Brokerage
#   Transaction_ID       Date  Amount_USD        Type    Account  Interest
# 0        TXN0001 2024-01-01     1903.97  Investment       Cash   3807.94
# 1        TXN0002 2024-01-02     4756.04  Investment       Cash   9512.08
# 2        TXN0003 2024-01-03     3673.37     Expense  Brokerage   7346.74

# %% [markdown]
# **Checking Last 3 Rows , tail() allows you to check last rows of your data**

# %%
financedf.tail(3)
# Out:
#    Transaction_ID       Date  Amount_USD        Type Account
# 97        TXN0098 2024-04-07     2166.33      Income    Cash
# 98        TXN0099 2024-04-08      175.82     Expense    Cash
# 99        TXN0100 2024-04-09      584.06  Investment    Cash
#    Transaction_ID       Date  Amount_USD        Type Account
# 97        TXN0098 2024-04-07     2166.33      Income    Cash
# 98        TXN0099 2024-04-08      175.82     Expense    Cash
# 99        TXN0100 2024-04-09      584.06  Investment    Cash

# %% [markdown]
# **Checking only data with type Income**

# %%
financedf[financedf ['Type']=='Income']
# Out:
#    Transaction_ID       Date  Amount_USD    Type      Account
# 4         TXN0005 2024-01-05      822.29  Income    Brokerage
# 16        TXN0017 2024-01-17     1556.00  Income         Cash
# 17        TXN0018 2024-01-18     2647.54  Income    Brokerage
# 18        TXN0019 2024-01-19     2188.13  Income  Credit Card
# 20        TXN0021 2024-01-21     3078.67  Income      Savings
# 23        TXN0024 2024-01-24     1863.49  Income      Savings
# 24        TXN0025 2024-01-25     2307.55  Income      Savings
# 25        TXN0026 2024-01-26     3936.62  Income  Credit Card
# 27        TXN0028 2024-01-28     2595.46  Income    Brokerage
# 31        TXN0032 2024-02-01      894.09  Income    Brokerage
# 36        TXN0037 2024-02-06     1557.84  Income      Savings
# 42        TXN0043 2024-02-12      220.22  Income         Cash
# 45        TXN0046 2024-02-15     3329.49  Income      Savings
# 49        TXN0050 2024-02-19      965.03  Income    Brokerage
# ...

# %% [markdown]
# **Checking Only Data with Cash Account**

# %%
financedf[financedf ['Account']=='Cash']
# Out:
#    Transaction_ID       Date  Amount_USD        Type Account
# 0         TXN0001 2024-01-01     1903.97  Investment    Cash
# 1         TXN0002 2024-01-02     4756.04  Investment    Cash
# 3         TXN0004 2024-01-04     3013.36     Expense    Cash
# 9         TXN0010 2024-01-10     3554.96  Investment    Cash
# 10        TXN0011 2024-01-11      151.89  Investment    Cash
# 12        TXN0013 2024-01-13     4170.59     Expense    Cash
# 15        TXN0016 2024-01-16      957.85  Investment    Cash
# 16        TXN0017 2024-01-17     1556.00      Income    Cash
# 19        TXN0020 2024-01-20     1491.58     Expense    Cash
# 22        TXN0023 2024-01-23     1496.12     Expense    Cash
# 32        TXN0033 2024-02-02      372.01     Expense    Cash
# 33        TXN0034 2024-02-03     4746.98     Expense    Cash
# 35        TXN0036 2024-02-05     4051.57  Investment    Cash
# 37        TXN0038 2024-02-07      533.48     Expense    Cash
# ...

# %% [markdown]
# **Checking Data of year 2024 january 1st and after that**

# %%
financedf[financedf['Date'] >= '2024-01-01']
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage
# ..            ...        ...         ...         ...        ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash
# 97        TXN0098 2024-04-07     2166.33      Income       Cash
# 98        TXN0099 2024-04-08      175.82     Expense       Cash
# 99        TXN0100 2024-04-09      584.06  Investment       Cash
#
# [100 rows x 5 columns]
#    Transaction_ID       Date  Amount_USD        Type    Account
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash
# ...

# %% [markdown]
# ** Checking numbers of Brokerage Accounts**

# %%
total = financedf[financedf ['Account']=='Brokerage'].count()

total
# Out:
# Transaction_ID    21
# Date              21
# Amount_USD        21
# Type              21
# Account           21
# dtype: int64
# Transaction_ID    21
# Date              21
# Amount_USD        21
# Type              21
# Account           21
# dtype: int64

# %% [markdown]
# **Adding New Column to Data Frame**

# %%
financedf['Interest'] = financedf['Amount_USD'] * 2
financedf
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account  Interest
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash   3807.94
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash   9512.08
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage   7346.74
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash   6026.72
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage   1644.58
# ..            ...        ...         ...         ...        ...       ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash   4988.58
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash   5275.06
# 97        TXN0098 2024-04-07     2166.33      Income       Cash   4332.66
# 98        TXN0099 2024-04-08      175.82     Expense       Cash    351.64
# 99        TXN0100 2024-04-09      584.06  Investment       Cash   1168.12
#
# [100 rows x 6 columns]
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=financedf)
# Out:
# https://docs.google.com/spreadsheets/d/18TXY0dINHUw5YLYdUJvnvAGMX341CJkBQSyWZleEv0I/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/18TXY0dINHUw5YLYdUJvnvAGMX341CJkBQSyWZleEv0I/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Type

from matplotlib import pyplot as plt
import seaborn as sns
financedf.groupby('Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Amount_USD

from matplotlib import pyplot as plt
financedf['Amount_USD'].plot(kind='line', figsize=(8, 4), title='Amount_USD')
#plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# <Axes: title={'center': 'Amount_USD'}>

# %%
financedf['Loan'] = financedf['Type'].apply(lambda x: 'Approved' if x =='Investment' else 'Not Approved')
financedf
# Out:
#    Transaction_ID       Date  Amount_USD        Type    Account          Loan
# 0         TXN0001 2024-01-01     1903.97  Investment       Cash      Approved
# 1         TXN0002 2024-01-02     4756.04  Investment       Cash      Approved
# 2         TXN0003 2024-01-03     3673.37     Expense  Brokerage  Not Approved
# 3         TXN0004 2024-01-04     3013.36     Expense       Cash  Not Approved
# 4         TXN0005 2024-01-05      822.29      Income  Brokerage  Not Approved
# ..            ...        ...         ...         ...        ...           ...
# 95        TXN0096 2024-04-05     2494.29     Expense       Cash  Not Approved
# 96        TXN0097 2024-04-06     2637.53  Investment       Cash      Approved
# 97        TXN0098 2024-04-07     2166.33      Income       Cash  Not Approved
# 98        TXN0099 2024-04-08      175.82     Expense       Cash  Not Approved
# 99        TXN0100 2024-04-09      584.06  Investment       Cash      Approved
#
# [100 rows x 6 columns]

# %%
# @title Loan

from matplotlib import pyplot as plt
import seaborn as sns
financedf.groupby('Loan').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
#plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# <Axes: ylabel='Loan'>
